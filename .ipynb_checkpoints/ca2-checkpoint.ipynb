# %% [markdown]
# # RESEARCH QUESTION
# #### "How do fresh graduate salaries compare to experienced workforce benchmarks, and which degree fields provide the strongest start in Singapore's job market?"
#
# ### Sub Questions
# - How do graduate starting salaries compare to overall workforce median salaries by occupation?
# - Which degree fields are "outperforming" (starting salaries competitive with workforce) vs "lagging behind"?
# - How has the graduate-to-workforce salary ratio changed from 2013-2022?
# - Is there a trade-off between employment rate and salary competitiveness?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
#    year                        university  \
# 0  2013  Nanyang Technological University
# 1  2013  Nanyang Technological University
# 2  2013  Nanyang Technological University
# 3  2013  Nanyang Technological University
# 4  2013  Nanyang Technological University
#
#                                           school  \
# 0  College of Business (Nanyang Business School)
# 1  College of Business (Nanyang Business School)
# 2  College of Business (Nanyang Business School)
# 3  College of Business (Nanyang Business School)
# 4                         College of Engineering
#
#                                         degree  Key
# 0                     Accountancy and Business    1
# 1  Accountancy (3-yr direct Honours Programme)    2
# 2     Business (3-yr direct Honours Programme)    3
# 3                       Business and Computing    4
# 4                        Aerospace Engineering    5

# %%
df1 = pd.read_csv('CA2 Datasets\CA2 Datasets\(1) graduate employment survey modified.csv')
df1.head()

# %%
df2 = pd.read_csv('CA2 Datasets\CA2 Datasets\(2) graduate employment survey modified .csv')
df2.head()
# Out:
#   employment_rate_overall employment_rate_ft_perm basic_monthly_mean  \
# 0                    97.4                    96.1               3701
# 1                    97.1                    95.7               2850
# 2                    90.9                    85.7               3053
# 3                    87.5                    87.5               3557
# 4                    95.3                    95.3               3494
#
#   basic_monthly_median gross_monthly_mean gross_monthly_median  \
# 0                 3200               3727                 3350
# 1                 2700               2938                 2700
# 2                 3000               3214                 3000
# 3                 3400               3615                 3400
# 4                 3500               3536                 3500
#
#   gross_mthly_25_percentile gross_mthly_75_percentile gross_monthly_mean.1  \
# 0                      2900                      4000                 3727
# ...
